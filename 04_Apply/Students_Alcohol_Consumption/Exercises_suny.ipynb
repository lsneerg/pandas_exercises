# %% [markdown]
# <a href="https://colab.research.google.com/github/lsneerg/pandas_exercises/blob/master/04_Apply/Students_Alcohol_Consumption/Exercises_suny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df = df.loc[:, 'school':'guardian']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   school    395 non-null    object
#  1   sex       395 non-null    object
#  2   age       395 non-null    int64
#  3   address   395 non-null    object
#  4   famsize   395 non-null    object
#  5   Pstatus   395 non-null    object
#  6   Medu      395 non-null    int64
#  7   Fedu      395 non-null    int64
#  8   Mjob      395 non-null    object
#  9   Fjob      395 non-null    object
#  10  reason    395 non-null    object
#  11  guardian  395 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 37.2+ KB

# %%
df.describe()
# Out:
#               age        Medu        Fedu
# count  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519
# std      1.276043    1.094735    1.088201
# min     15.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000
# 50%     17.000000    3.000000    2.000000
# 75%     18.000000    4.000000    3.000000
# max     22.000000    4.000000    4.000000

# %%
df.sample(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 83      GP   M   15       U     LE3       T     2     2  services  services
# 269     GP   F   18       R     GT3       T     2     1     other     other
# 86      GP   F   16       U     LE3       T     2     2   at_home     other
# 200     GP   F   16       U     GT3       T     4     3    health     other
# 194     GP   M   16       U     GT3       T     2     3     other     other
#
#          reason guardian
# 83         home   mother
# 269  reputation   mother
# 86       course   mother
# 200        home   mother
# 194        home   father

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
cap = lambda x: x.capitalize() if isinstance(x, str) else x

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df[['Mjob', 'Fjob']] = df[['Mjob', 'Fjob']].map(cap)

# %%
df.sample(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 85      GP   F   15       U     GT3       T     4     4  Services  Services
# 105     GP   F   15       U     GT3       A     3     3     Other    Health
# 323     GP   F   17       U     GT3       T     3     1  Services  Services
# 206     GP   F   16       U     GT3       A     3     1  Services     Other
# 377     MS   F   18       R     LE3       T     4     4   Teacher  Services
#
#          reason guardian  legal_drinker
# 85   reputation   father          False
# 105  reputation   father          False
# 323      course   father          False
# 206      course   mother          False
# 377      course   mother           True

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  \
# 394     MS   M   19       U     LE3       T     1     1  Other  At_home
#
#      reason guardian  legal_drinker
# 394  course   father           True

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
majority = lambda x: x > 17

# %%
df['legal_drinker'] = df['age'].map(majority)

# %%
df.sample(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 84      GP   F   15       U     GT3       T     1     1     Other     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 221     GP   F   17       U     GT3       T     1     1   At_home     Other
# 45      GP   F   15       U     LE3       A     4     3     Other     Other
# 337     GP   F   17       U     GT3       T     3     2     Other     Other
# 173     GP   F   16       U     GT3       T     1     3   At_home  Services
# 358     MS   M   18       U     LE3       T     1     1     Other  Services
# 107     GP   M   16       U     GT3       T     3     3  Services     Other
# 379     MS   F   17       R     GT3       T     3     1   At_home     Other
# 81      GP   M   15       U     GT3       T     2     3     Other     Other
#
#          reason guardian  legal_drinker
# 84         home   father          False
# 6          home   mother          False
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df.map(lambda x: x * 10 if isinstance(x, int) else x)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   At_home   Teacher
# 1       GP   F  170       U     GT3       T    10    10   At_home     Other
# 2       GP   F  150       U     LE3       T    10    10   At_home     Other
# 3       GP   F  150       U     GT3       T    40    20    Health  Services
# 4       GP   F  160       U     GT3       T    30    30     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M  200       U     LE3       A    20    20  Services  Services
# 391     MS   M  170       U     LE3       T    30    10  Services  Services
# 392     MS   M  210       R     GT3       T    10    10     Other     Other
# 393     MS   M  180       R     LE3       T    30    20  Services     Other
# 394     MS   M  190       U     LE3       T    10    10     Other   At_home
#
#      reason guardian  legal_drinker
# ...
