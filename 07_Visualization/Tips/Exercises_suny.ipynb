# %% [markdown]
# <a href="https://colab.research.google.com/github/lsneerg/pandas_exercises/blob/master/07_Visualization/Tips/Exercises_suny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'
tips = pd.read_csv(url).iloc[:, 1:]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
sns.histplot(
    tips.total_bill
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip',
    # size='size',
    # sizes=(10,150)
    hue='size'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 114       25.71  4.00  Female     No   Sun  Dinner     3
# 35        24.06  3.60    Male     No   Sat  Dinner     3
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2

# %%
grouped = tips.groupby('day').agg({
    'total_bill': 'sum'
})
sns.barplot(
    data=grouped,
    x='day',
    y='total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(
    data=tips,
    x='day',
    y='total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 116       29.93  5.07    Male     No   Sun  Dinner     4
# 79        17.29  2.71    Male     No  Thur   Lunch     2

# %%
sns.scatterplot(
    data=tips,
    x='tip',
    y='day',
    hue='sex'
    # jitter = True
)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 99        12.46  1.50    Male     No   Fri  Dinner     2
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2
# 59        48.27  6.73    Male     No   Sat  Dinner     4

# %%
sns.boxplot(
    data=tips,
    x='day',
    y='total_bill',
    hue='time'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
timed = tips.groupby(['day', 'time'])

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 45        18.29  3.00    Male     No   Sun  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 206       26.59  3.41    Male    Yes   Sat  Dinner     3

# %%
sns.scatterplot(
    data=tips,

)

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
